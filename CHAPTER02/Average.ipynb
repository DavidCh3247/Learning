# %% [markdown]
# ### Task #2: Process the data in the file
# #### * 2a  Read the lines from the file
# #### * 2b  Ignore the second line
# #### * 2c  Break the first line apart by “,” to produce a list of times
# #### * 2d  Take each of the times and convert them to a number from the “mins:secs.hundredths” format
# #### * 2e  Calculate the average time, then convert it back to the “mins:secs.hundredths” format (for display purposes)
# #### * 2f  Display the variables from Task #1, then the list of times, and the calculated average from Task #2

# %% [markdown]
# *2a  Read the lines from the file*
# ---------------------------------

# %%
FN = "Darius-13-100m-Fly.txt"

# %%
FOLDER = "swimdata/"

# %%
with open(FOLDER + FN) as file:
    lines = file.readlines()

# %%
type(file)
# Out:
# _io.TextIOWrapper

# %%
print(dir(file))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %% [markdown]
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', '*readline*', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines'

# %%
type(lines)
# Out:
# list

# %% [markdown]
# #### *2b  Ignore the second line*

# %%
lines
# Out:
# ['1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n']

# %%
lines[0]
# Out:
# '1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n'

# %%
type(lines[0])
# Out:
# str

# %% [markdown]
# #### *2c  Break the first line apart by “,” to produce a list of times*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *In Python, the strip() method is used to remove leading and trailing whitespace characters (spaces, tabs, and newlines) from a string. It returns a new string with the whitespace characters removed. The original string remains unchanged.*

# %%
lines [0].strip().split(",")
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
times = lines[0].strip().split(",")

# %%
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
type(times)
# Out:
# list

# %% [markdown]
# #### *2d  Take each of the times and convert them to a number from the “mins:secs.hundredths” format*

# %%
times[0]
# Out:
# '1:27.95'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *To hundredths of seconds with Python*

# %%
#start with the string.
first = times[0]

# %%
#Extract the component parts: start with the minutes value
minutes, rest = first.split(":")
# Extract the component parts: grab the seconds and hundredths values.
seconds, hundredths = rest.split(".")

# %%
#Convert the strings to numbers with the help of another BIF called
# "int", then perform the calculation
converted_time = (int(minutes)*60*100) + (int(seconds)*100) + int(hundredths)

# %%
# Display the result.
print(converted_time)
# Out:
# 8795

# %%
for t in times:
    print(t)
# Out:
# 1:27.95
# 1:21.07
# 1:30.96
# 1:23.22
# 1:27.95
# 1:28.30

# %%
len(times)
# Out:
# 6

# %%
for t in times:
    minutes, rest = t.split(":")
    seconds, hundredths = rest.split(".")
    print(t, "->", (int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths))
# Out:
# 1:27.95 -> 8795
# 1:21.07 -> 8107
# 1:30.96 -> 9096
# 1:23.22 -> 8322
# 1:27.95 -> 8795
# 1:28.30 -> 8830

# %% [markdown]
# #### * *2e  Calculate the average time, then convert it back to the “mins:secs.hundredths” format (for display purposes)*

# %% [markdown]
# Displaying a list of your list’s methods

# %%
converts = []
for t in times:
    minutes, rest = t.split(":")
    seconds, hundredths = rest.split(".")
    converts.append((int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths))

# %%
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
converts
# Out:
# [8795, 8107, 9096, 8322, 8795, 8830]

# %% [markdown]
# *It’s time to calculate the average*

# %%
import statistics

# %%
statistics.mean(converts)
# Out:
# 8657.5

# %%
print(dir(statistics))
# Out:
# ['Counter', 'Decimal', 'Fraction', 'LinearRegression', 'NormalDist', 'StatisticsError', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_coerce', '_convert', '_exact_ratio', '_fail_neg', '_find_lteq', '_find_rteq', '_isfinite', '_normal_dist_inv_cdf', '_ss', '_sum', 'bisect_left', 'bisect_right', 'correlation', 'covariance', 'erf', 'exp', 'fabs', 'fmean', 'fsum', 'geometric_mean', 'groupby', 'harmonic_mean', 'hypot', 'itemgetter', 'linear_regression', 'log', 'math', 'mean', 'median', 'median_grouped', 'median_high', 'median_low', 'mode', 'multimode', 'namedtuple', 'numbers', 'pstdev', 'pvariance', 'quantiles', 'random', 'repeat', 'sqrt', 'stdev', 'tau', 'variance']

# %% [markdown]
# ['Counter', 'Decimal', 'Fraction', 'LinearRegression', 'NormalDist', 'StatisticsError', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_coerce', '_convert', '_exact_ratio', '_fail_neg', '_find_lteq', '_find_rteq', '_isfinite', '_normal_dist_inv_cdf', '_ss', '_sum', 'bisect_left', 'bisect_right', 'correlation', 'covariance', 'erf', 'exp', 'fabs', 'fmean', 'fsum', 'geometric_mean', 'groupby', 'harmonic_mean', 'hypot', 'itemgetter', 'linear_regression', 'log', 'math', 'mean', 'median', 'median_grouped', 'median_high', 'median_low', 'mode', 'multimode', 'namedtuple', 'numbers', 'pstdev', 'pvariance', 'quantiles', 'random', 'repeat', 'sqrt', 'stdev', 'tau', 'variance']

# %% [markdown]
# *Convert the average to a swim time string*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
average = statistics.mean(converts)

# %%
average / 100     #Dividing by 100 gives you the second and hundreths of second values
# Out:
# 86.575

# %%
round(average / 100, 2)   # BIF (round) rounds your division to two decimal points
# Out:
# 86.58

# %%
str(round(average / 100, 2)).split(".")
# Out:
# ['86', '58']

# %%
min_secs, hundreths = str(round(average / 100, 2)).split(".")

# %%
min_secs = int(min_secs)        #converting string min_secs to integers

# %%
minutes = min_secs // 60    # // operator rounds down to the nearest integer

# %%
minutes
# Out:
# 1

# %%
seconds = min_secs - minutes*60    #the number os seconds after the number of minutes are substracted from 86

# %%
seconds
# Out:
# 26

# %% [markdown]
# *With minutes, seconds, and hundredths now known, build the swim time string.*

# %%
minutes, seconds, hundreths
# Out:
# (1, 26, '58')

# %%
str(minutes) + ":" +str(seconds) + "." + hundreths   #"hundreths" is already a string
# Out:
# '1:26.58'

# %%
average = str(minutes) + ":" +str(seconds) + "." + hundreths

# %%
average
# Out:
# '1:26.58'

# %% [markdown]
# **2f** Display the variables from Task #1, then the list of 2f times, and the calculated average from Task #2.
